# %%
import json
import networkx as nx
import pandas as pd

# %%
def load_graph_from_data(filename: str = "data_cache/graph_data.json"):
    """Load a graph from a JSON file containing nodes and edges."""
    with open(filename, "r") as f:
        data = json.load(f)
    
    graph = nx.Graph()
    graph.add_nodes_from(data["nodes"])
    graph.add_edges_from(data["edges"])

    return graph

# %%
graph = load_graph_from_data()

# %% [markdown]
# ### Node Data

# %%
list(graph.nodes(data=True))[0]
# Out:
# ('fabianocaruana',
#  {'uid': 11177810,
#   'name': 'Fabiano Caruana',
#   'username': 'fabianocaruana',
#   'country': 'US',
#   'rating': 2823})

# %% [markdown]
# ### Edge Data

# %%
list(graph.edges(data=True))[0]
# Out:
# ('fabianocaruana',
#  'vincentkeymer',
#  {'weight': 50,
#   'data': [{'pgn': '[Event "Live Chess"]\n[Site "Chess.com"]\n[Date "2024.10.01"]\n[Round "-"]\n[White "VincentKeymer"]\n[Black "FabianoCaruana"]\n[Result "0-1"]\n[CurrentPosition "8/5p2/2n5/1k2pP1p/1b2P1p1/1p1K2P1/3B4/1N6 w - -"]\n[Timezone "UTC"]\n[ECO "A30"]\n[ECOUrl "https://www.chess.com/openings/English-Opening-Symmetrical-Variation...5.Bg2-Nc6-6.Nc3-g6"]\n[UTCDate "2024.10.01"]\n[UTCTime "15:15:45"]\n[WhiteElo "2779"]\n[BlackElo "2817"]\n[TimeControl "600+2"]\n[Termination "FabianoCaruana won on time"]\n[StartTime "15:15:45"]\n[EndDate "2024.10.01"]\n[EndTime "15:39:16"]\n[Link "https://www.chess.com/game/live/121534814803"]\n\n1. c4 {[%clk 0:10:02]} 1... c5 {[%clk 0:10:00.1]} 2. Nf3 {[%clk 0:09:57.5]} 2... Nf6 {[%clk 0:10:00.3]} 3. Nc3 {[%clk 0:09:58.5]} 3... Nc6 {[%clk 0:10:01]} 4. g3 {[%clk 0:09:59.9]} 4... d5 {[%clk 0:10:01.5]} 5. cxd5 {[%clk 0:10:00]} 5... Nxd5 {[%clk 0:10:03.4]} 6. Bg2 {[%clk 0:10:01.5]} 6... g6 {[%clk 0:10:04.2]} 7. h4 {[%clk 0:10:02.6]} 7... h6 {[%clk 0:10:04.5]} 8. d3 {[%clk 0:09:30.4]} 8... Be6 {[%clk 0:10:00.2]} 9. O-O {[%clk 0:08:58.3]} 9... Bg7 {[%clk 0:09:59.7]} 10. Bd2 {[%clk 0:08:56.4]} 10... b6 {[%clk 0:09:30.5]} 11. a3 {[%clk 0:08:36.6]} 11... Rc8 {[%clk 0:09:09.9]} 12. Rc1 {[%clk 0:08:35.1]} 12... a5 {[%clk 0:08:02.6]} 13. Qa4 {[%clk 0:07:43.8]} 13... O-O {[%clk 0:07:44.2]} 14. Rfd1 {[%clk 0:07:25.9]} 14... Qd7 {[%clk 0:07:19.6]} 15. Qb5 {[%clk 0:07:08.5]} 15... Qb7 {[%clk 0:06:21]} 16. Nxd5 {[%clk 0:04:01.7]} 16... Bxd5 {[%clk 0:06:22.9]} 17. Bc3 {[%clk 0:03:16.6]} 17... e5 {[%clk 0:06:08.2]} 18. h5 {[%clk 0:02:41.8]} 18... Na7 {[%clk 0:05:13.9]} 19. Qa4 {[%clk 0:02:39.8]} 19... b5 {[%clk 0:05:15.2]} 20. Qg4 {[%clk 0:01:41.7]} 20... g5 {[%clk 
#     'time_control': '600+2',
#     'time_class': 'rapid',
#     'rules': 'chess',
#     'accuracies': {'white': 88.77, 'black': 93.94},
#     'eco_code': 'https://www.chess.com/openings/English-Opening-Symmetrical-Variation...5.Bg2-Nc6-6.Nc3-g6',
#     'white': {'uid': '9118af64-0e4f-11e8-805a-000000000000',
#      'username': 'VincentKeymer',
#      'rating': 2779,
#      'result': 'timeout'},
#     'black': {'uid': '5ebdca54-8f15-11e2-800a-000000000000',
#      'username': 'FabianoCaruana',
#      'rating': 2817,
#      'result': 'win'},
#     'start_time': 0,
#     'end_time': 1727797156,
#     'duration': 1727797156},
#    {'pgn': '[Event "Live Chess"]\n[Site "Chess.com"]\n[Date "2024.10.01"]\n[Round "-"]\n[White "VincentKeymer"]\n[Black "FabianoCaruana"]\n[Result "1/2-1/2"]\n[CurrentPosition "k7/8/PK6/8/8/6B1/8/8 b - -"]\n[Timezone "UTC"]\n[ECO "A30"]\n[ECOUrl "https://www.chess.com/openings/English-Opening-Symmetrical-Variation-2.Nf3-Nc6-3.b3-Nf6-4.Bb2"]\n[UTCDate "2024.10.01"]\n[UTCTime "16:01:54"]\n[WhiteElo "2773"]\n[BlackElo "2823"]\n[TimeControl "600+2"]\n[Termination "Game drawn by stalemate"]\n[StartTime "16:01:54"]\n[EndDate "2024.10.01"]\n[EndTime "16:24:08"]\n[Link "https://www.chess.com/game/live/121537292383"]\n\n1. Nf3 {[%clk 0:09:57]} 1... c5 {[%clk 0:09:59.9]} 2. c4 {[%clk 0:09:57.8]} 2... Nf6 {[%clk 0:10:00.2]} 3. b3 {[%clk 0:09:59]} 3... Nc6 {[%clk 0:09:55.2]} 4. Bb2 {[%clk 0:09:59.8]} 4... d5 {[%clk 0:09:56.5]} 5. cxd5 {[%clk 0:10:01.7]} 5... Nxd5 {[%clk 0:09:58]} 6. Nc3 {[%clk 0:09:42.4]} 6... Nxc3 {[%clk 0:09:21]} 7. Bxc3 {[%clk 0:09:41.6]} 7... f6 {[%clk 0:09:21.6]} 8. e3 {[%clk 0:09:41.8]} 8... e5 {[%clk 0:09:21.8]} 9. Bc4 {[%clk 0:09:43.1]} 9... Qd6 {[%clk 0:07:46.6]} 10. O-O {[%clk 0:09:02.8]} 10... Be6 {[%clk 0:07:46.3]} 11. d4 {[%clk 0:08:35.2]} 11... Bxc4 {[%clk 0:07:31]} 12. bxc4 {[%clk 0:08:34.9]} 12... cxd4 {[%clk 0:07:32.3]} 13. exd4 {[%clk 0:08:35.9]} 13... exd4 {[%clk 0:07:33.3]} 14. Nxd4 {[%clk 0:08:28.1]} 14... Nxd4 {[%clk 0:07:30.7]} 15. Bxd4 {[%clk 0:08:14.8]} 15... O-O-O {[%clk 0:07:02.4]} 16. Bxa7 {[%clk 0:07:25]} 16... Qxd1 {[%clk 0:07:01.9]} 17. Rfxd1 {[%clk 0:07:16.9]} 17... Rxd1+ {[%clk 0:07:03.8]} 18. Rxd1 {[%clk 0:07:16.7]} 18... Kc7 {[%clk 0:06:56.5]} 19. Be3 {[%clk 0:04:02.9]} 19... Be7 {[%clk 0:06:28.9]} 20. Kf1 {[%clk 0:02:42.4]} 20... Ra8 {[%clk 0:06:27.5]} 21. Rd2 {[%clk 0:02:43.9]} 21... Ra4 {[%clk 0:05:42
#     'time_control': '600+2',
#     'time_class': 'rapid',
#     'rules': 'chess',
#     'accuracies': {'white': 98.04, 'black': 97.85},
#     'eco_code': 'https://www.chess.com/openings/English-Opening-Symmetrical-Variation-2.Nf3-Nc6-3.b3-Nf6-4.Bb2',
#     'white': {'uid': '9118af64-0e4f-11e8-805a-000000000000',
#      'username': 'VincentKeymer',
#      'rating': 2773,
#      'result': 'stalemate'},
#     'black': {'uid': '5ebdca54-8f15-11e2-800a-000000000000',
#      'username': 'FabianoCaruana',
#      'rating': 2823,
#      'result': 'stalemate'},
#     'start_time': 0,
#     'end_time': 1727799848,
#     'duration': 1727799848}]})

# %% [markdown]
# ### Degree: Measures the number of direct connections

# %%
pd.DataFrame(dict(graph.degree()), index=["degree"]).T.sort_values("degree", ascending=False).head(20)
# Out:
#                     degree
# the_machine04          170
# fitod                   98
# anasta10                97
# yanhob                  93
# mklose11                87
# yaacovn                 80
# rezamahdavi2008         65
# 0blivi0usspy            63
# eagle_2019              59
# jcibarra                45
# onyshchuk_v             42
# fabianocaruana          36
# jefferyx                32
# h4parah5                29
# vincent_vega95          21
# antipov_mikhail_al      15
# vincentkeymer           12
# koksal06                10
# volodar_murzin           9
# chessgodisback2008       5

# %% [markdown]
# ### Betweenness: Nodes that act as bridges within the network

# %%
pd.DataFrame(nx.betweenness_centrality(graph, weight='weight'), index=["betweenness"]).T.sort_values("betweenness", ascending=False).head(20)
# Out:
#                     betweenness
# anasta10               0.366680
# the_machine04          0.360734
# yaacovn                0.206851
# yanhob                 0.202141
# fitod                  0.182639
# chessgodisback2008     0.157372
# 0blivi0usspy           0.155314
# mklose11               0.154071
# tanitoluwaaps116       0.127031
# jcibarra               0.124043
# rezamahdavi2008        0.114229
# onyshchuk_v            0.097753
# eagle_2019             0.076948
# fabianocaruana         0.074499
# jefferyx               0.068968
# carokannlover213       0.065537
# gamayevoleg            0.057090
# h4parah5               0.051372
# miterryble             0.042433
# pyrihroman             0.041766

# %% [markdown]
# ### Pagerank: Identifies influential players

# %%
pd.DataFrame(nx.pagerank(graph, weight='weight'), index=["pagerank"]).T.sort_values("pagerank", ascending=False).head(20)
# Out:
#                     pagerank
# the_machine04       0.077607
# yanhob              0.051925
# fitod               0.050356
# anasta10            0.039886
# mklose11            0.034850
# yaacovn             0.033589
# rezamahdavi2008     0.027263
# 0blivi0usspy        0.023514
# eagle_2019          0.023221
# fabianocaruana      0.021693
# jcibarra            0.019642
# onyshchuk_v         0.016796
# h4parah5            0.012738
# jefferyx            0.011782
# vincent_vega95      0.010606
# antipov_mikhail_al  0.008152
# vincentkeymer       0.005506
# nikitashandrygin    0.004577
# turboplombir        0.003727
# koksal06            0.003662

# %% [markdown]
# ### Win Ratio Analysis

# %%
win_loss_ratio = {}
for u, v, data in graph.edges(data=True):
    games = data.get('data', [])
    for game in games:
        white_result = game['white']['result']
        black_result = game['black']['result']
        if white_result == "win":
            winner = game['white']['username']
            loser = game['black']['username']
        elif black_result == "win":
            winner = game['black']['username']
            loser = game['white']['username']
        else:
            continue
        if winner not in win_loss_ratio:
            win_loss_ratio[winner] = {"wins": 0, "losses": 0}
        if loser not in win_loss_ratio:
            win_loss_ratio[loser] = {"wins": 0, "losses": 0}
        win_loss_ratio[winner]["wins"] += 1
        win_loss_ratio[loser]["losses"] += 1

df = pd.DataFrame(win_loss_ratio).T
df['ratio'] = df['wins'] / (df['wins'] + df['losses'])
df[df['wins'] + df['losses'] > 10].sort_values("ratio", ascending=False).head(20)
# Out:
#                     wins  losses     ratio
# FabianoCaruana        44       9  0.830189
# Antipov_Mikhail_Al    19       4  0.826087
# jefferyx              20       5  0.800000
# jcibarra              38      12  0.760000
# Yaacovn               95      40  0.703704
# onyshchuk_v           29      13  0.690476
# h4parah5              20      11  0.645161
# 0blivi0usspy          74      44  0.627119
# rezamahdavi2008       86      54  0.614286
# Eagle_2019            52      36  0.590909
# fitod                 72      51  0.585366
# The_Machine04        124      95  0.566210
# Rud_Makarian           6       5  0.545455
# Vincent_Vega95        12      10  0.545455
# Volodar_Murzin         7       6  0.538462
# Yanhob                73      65  0.528986
# DanielNaroditsky      10       9  0.526316
# Adham_Fawzy           10       9  0.526316
# anasta10              63      61  0.508065
# Akhmedov_David         7       7  0.500000

# %% [markdown]
# ### Game time analysis?

# %%
avg_durations = {}
for u, v, data in graph.edges(data=True):
    durations = [game['duration'] for game in data['data']]
    avg_durations[(u, v)] = sum(durations) / len(durations)
df = pd.DataFrame(avg_durations, index=["avg_duration"]).T
df["avg_duration"] = df["avg_duration"] / (60 * 60 * 24 * 365)  # The heck is the unit of duration? haha
df.sort_values("avg_duration", ascending=False).head(20)
# Out:
#                                     avg_duration
# 0blivi0usspy    dafny2005              54.843345
#                 lonelyqueen0           54.843198
#                 blefer66               54.843187
#                 masruri_rahman         54.842795
#                 nikitakhoroshev        54.842537
#                 turboplombir           54.842523
#                 oskariot               54.842513
# seochesspie     0blivi0usspy           54.837436
# blitzstream     0blivi0usspy           54.835296
# gilbertelroy    0blivi0usspy           54.835286
# 0blivi0usspy    forevery0ung           54.835193
#                 alexrustemov           54.835178
# onyshchuk_v     bryanl106              54.827257
#                 happy1712drummer       54.827226
# rezamahdavi2008 cayse                  54.827220
#                 ilanschnaider          54.827203
#                 chessgodisback2008     54.827179
# onyshchuk_v     crazy_but_lazy         54.827162
# rezamahdavi2008 artemdyachuk           54.827160
# vincentkeymer   onyshchuk_v            54.827129

# %% [markdown]
# ### Communities: Investigate communities within the graph (Level = # of splits | ID = Unique community)

# %%
from itertools import islice


community_levels = list(islice(nx.community.girvan_newman(graph), 3))

# %%
data = []
for level, partition in enumerate(community_levels, 1):
    for community_id, community in enumerate(partition):
        for node in community:
            data.append({
                "Node": node,
                "Community_Level": level,
                "Community_ID": community_id
            })

df = pd.DataFrame(data)
df.groupby(["Community_Level", "Community_ID"]).size().reset_index(name="Node_Count")
# Out:
#    Community_Level  Community_ID  Node_Count
# 0                1             0         615
# 1                1             1         185
# 2                2             0         615
# 3                2             1          92
# 4                2             2          93
# 5                3             0         600
# 6                3             1          92
# 7                3             2          93
# 8                3             3          15
