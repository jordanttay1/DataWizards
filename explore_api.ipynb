# %%
# %reload_ext autoreload
# %autoreload 2

# %%
from chessdotcom import (
    Client,
    get_player_profile,
    get_titled_players,
    get_player_current_games,
    get_player_current_games_to_move,
    get_player_games_by_month,
    get_player_games_by_month_pgn,
    get_player_clubs,
    get_player_team_matches,
    get_player_tournaments,
    get_club_details,
    get_club_members,
    get_club_matches,
    get_leaderboards,
    get_streamers,
    get_player_stats,
    get_player_game_archives,
    get_random_daily_puzzle,
    get_current_daily_puzzle,
    get_country_details,
    get_country_players,
    get_country_clubs
)

Client.request_config["headers"]["User-Agent"] = (
    "My Python Application. " "Contact me at email@example.com"
)
username = "fabianocaruana"

# %% [markdown]
# ## Get Player Profile

# %%
get_player_profile?
# Out:
# Signature: get_player_profile(username: str, tts=0, **kwargs) -> chessdotcom.types.ChessDotComResponse
# Docstring:
# :param username: username of the player.
# :param tts: the time the client will wait before making the first request.
# :returns: ``ChessDotComResponse`` object containing information about
#             the player's profile.
# File:      ~/Documents/Projects/cse6242/project/.venv/lib/python3.10/site-packages/chessdotcom/client.py
# Type:      function

# %%
get_player_profile(username).json
# Out:
# {'player': {'avatar': 'https://images.chesscomfiles.com/uploads/v1/user/11177810.9dfc8d31.200x200o.9a9eccebc07c.png',
#   'player_id': 11177810,
#   '@id': 'https://api.chess.com/pub/player/fabianocaruana',
#   'url': 'https://www.chess.com/member/FabianoCaruana',
#   'name': 'Fabiano Caruana',
#   'username': 'fabianocaruana',
#   'title': 'GM',
#   'followers': 18977,
#   'country': 'https://api.chess.com/pub/country/US',
#   'last_online': 1726158940,
#   'joined': 1363533272,
#   'status': 'premium',
#   'is_streamer': False,
#   'verified': False,
#   'league': 'Champion',
#   'streaming_platforms': []}}

# %% [markdown]
# ## Get Titled Players

# %%
get_titled_players?
# Out:
# Signature: get_titled_players(title_abbrev: str, tts=0, **kwargs) -> chessdotcom.types.ChessDotComResponse
# Docstring:
# :param title_abbrev: abbreviation of chess title.
# :param tts: the time the client will wait before making the first request.
# :returns: ``ChessDotComResponse`` object containing a list of usernames.
# File:      ~/Documents/Projects/cse6242/project/.venv/lib/python3.10/site-packages/chessdotcom/client.py
# Type:      function

# %%
get_titled_players("GM").json.keys()
# Out:
# dict_keys(['players'])

# %% [markdown]
# ## Get Player Stats

# %%
get_player_stats?
# Out:
# Signature: get_player_stats(username: str, tts=0, **kwargs) -> chessdotcom.types.ChessDotComResponse
# Docstring:
# :param username: username of the player.
# :param tts: the time the client will wait before making the first request.
# :returns: ``ChessDotComResponse`` object containing information about the
#             plyers's ratings, win/loss, and other stats.
# File:      ~/Documents/Projects/cse6242/project/.venv/lib/python3.10/site-packages/chessdotcom/client.py
# Type:      function

# %%
get_player_stats(username).json
# Out:
# {'stats': {'chess_rapid': {'last': {'rating': 2763,
#     'date': 1721491677,
#     'rd': 43},
#    'best': {'rating': 3045,
#     'date': 1567282891,
#     'game': 'https://www.chess.com/game/live/87247703041'},
#    'record': {'win': 164, 'loss': 69, 'draw': 135}},
#   'chess_bullet': {'last': {'rating': 3152, 'date': 1722977255, 'rd': 34},
#    'best': {'rating': 3152,
#     'date': 1722977255,
#     'game': 'https://www.chess.com/game/live/88461616105'},
#    'record': {'win': 954, 'loss': 321, 'draw': 100}},
#   'chess_blitz': {'last': {'rating': 3127, 'date': 1726062681, 'rd': 40},
#    'best': {'rating': 3207,
#     'date': 1716676009,
#     'game': 'https://www.chess.com/game/live/78621077395'},
#    'record': {'win': 1856, 'loss': 558, 'draw': 348}},
#   'fide': 2835,
#   'tactics': {'highest': {'rating': 3519, 'date': 1686676974},
#    'lowest': {'rating': 1354, 'date': 1363907400}},
#   'puzzle_rush': {'best': {'total_attempts': 67, 'score': 64}}}}

# %% [markdown]
# ## Get Player Current Games

# %%
get_player_current_games?
# Out:
# Signature: get_player_current_games(username: str, tts=0, **kwargs) -> chessdotcom.types.ChessDotComResponse
# Docstring:
# :param username: username of the player.
# :param tts: the time the client will wait before making the first request.
# :returns: ``ChessDotComResponse`` object containing a list of Daily Chess games
#             that a player is currently playing.
# File:      ~/Documents/Projects/cse6242/project/.venv/lib/python3.10/site-packages/chessdotcom/client.py
# Type:      function

# %%
get_player_current_games(username).json
# Out:
# {'games': []}

# %%
get_player_current_games_to_move?
# Out:
# Signature: get_player_current_games_to_move(username: str, tts=0, **kwargs) -> chessdotcom.types.ChessDotComResponse
# Docstring:
# :param username: username of the player.
# :param tts: the time the client will wait before making the first request.
# :returns: ``ChessDotComResponse`` object containing a list of Daily Chess games
#             where it is the player's turn to act.
# File:      ~/Documents/Projects/cse6242/project/.venv/lib/python3.10/site-packages/chessdotcom/client.py
# Type:      function

# %%
get_player_current_games_to_move(username).json
# Out:
# {'games': []}

# %% [markdown]
# ## Get Player Game Archives

# %%
get_player_game_archives?
# Out:
# Signature: get_player_game_archives(username: str, tts=0, **kwargs) -> chessdotcom.types.ChessDotComResponse
# Docstring:
# :param username: username of the player.
# :param tts: the time the client will wait before making the first request.
# :returns: ``ChessDotComResponse`` object containing a
#             list of monthly archives available for this player.
# File:      ~/Documents/Projects/cse6242/project/.venv/lib/python3.10/site-packages/chessdotcom/client.py
# Type:      function

# %%
get_player_game_archives("moorgen").json
# Out:
# {'archives': ['https://api.chess.com/pub/player/moorgen/games/2021/07',
#   'https://api.chess.com/pub/player/moorgen/games/2022/01',
#   'https://api.chess.com/pub/player/moorgen/games/2023/01',
#   'https://api.chess.com/pub/player/moorgen/games/2023/02',
#   'https://api.chess.com/pub/player/moorgen/games/2024/03',
#   'https://api.chess.com/pub/player/moorgen/games/2024/06',
#   'https://api.chess.com/pub/player/moorgen/games/2024/08']}

# %%
get_player_games_by_month?
# Out:
# Signature:
# get_player_games_by_month(
#     username: str,
#     year: Union[str, int, NoneType] = None,
#     month: Union[str, int, NoneType] = None,
#     datetime_obj: Optional[datetime.datetime] = None,
#     tts=0,
#     **kwargs,
# ) -> chessdotcom.types.ChessDotComResponse
# Docstring:
# :param username: username of the player.
# :param year: the year (yyyy).
# :param month: the month (mm).
# :param date: datetime.datetime of the month. Can be passed in instead of month
#                 and year parameters.
# :param tts: the time the client will wait before making the first request.
# :returns: ``ChessDotComResponse`` object containing a list of live and daily
#             Chess games that a player has finished.
# File:      ~/Documents/Projects/cse6242/project/.venv/lib/python3.10/site-packages/chessdotcom/client.py
# Type:      function

# %%
get_player_games_by_month(username, "2021", "02").json
# Out:
# {'games': [{'url': 'https://www.chess.com/game/375c9fac-5f4c-11eb-b65b-afabb001000b',
# ...

# %%
get_player_games_by_month_pgn?
# Out:
# Signature:
# get_player_games_by_month_pgn(
#     username: str,
#     year: Union[str, int, NoneType] = None,
#     month: Union[str, int, NoneType] = None,
#     datetime_obj: Optional[datetime.datetime] = None,
#     tts=0,
#     **kwargs,
# ) -> chessdotcom.types.ChessDotComResponse
# Docstring:
# :param username: username of the player.
# :param year: the year (yyyy).
# :param month: the month (mm).
# :param date: datetime.datetime of the month. Can be passed in instead of month
#                 and year parameters.
# :returns: ``ChessDotComResponse`` object containing
#             standard multi-game format PGN containing all games for a month.
# File:      ~/Documents/Projects/cse6242/project/.venv/lib/python3.10/site-packages/chessdotcom/client.py
# Type:      function

# %%
get_player_games_by_month_pgn(username, "2021", "02").json['pgn']
# Out:
# {'pgn': '[Event "Let\'s Play"]\n[Site "Chess.com"]\n[Date "2021.02.21"]\n[Round "-"]\n[White "stlfelix"]\n[Black "FabianoCaruana"]\n[Result "0-1"]\n[CurrentPosition "2kr4/ppp2p2/3p3p/8/2PpP1nP/P2P1PP1/2P2q2/R2Q1K2 w - - 3 22"]\n[Timezone "UTC"]\n[ECO "C47"]\n[ECOUrl "https://www.chess.com/openings/Four-Knights-Game-4.Be2-Bb4"]\n[UTCDate "2021.02.21"]\n[UTCTime "01:02:17"]\n[WhiteElo "1128"]\n[BlackElo "400"]\n[TimeControl "1/86400"]\n[Termination "FabianoCaruana won by checkmate"]\n[StartTime "01:02:17"]\n[EndDate "2021.02.23"]\n[EndTime "17:55:08"]\n[Link "https://www.chess.com/game/daily/313413728"]\n\n1. e4 {[%clk 0:00:09.6]} 1... e5 {[%clk 0:01:01.3]} 2. Nf3 {[%clk 0:02:29]} 2... Nc6 {[%clk 0:00:20.4]} 3. Nc3 {[%clk 0:14:36.5]} 3... Nf6 {[%clk 0:00:15.4]} 4. Be2 {[%clk 0:00:05.8]} 4... Bb4 {[%clk 0:00:01.2]} 5. a3 {[%clk 0:00:01]} 5... Bxc3 {[%clk 0:01:26.4]} 6. bxc3 {[%clk 0:56:01.3]} 6... d6 {[%clk 0:00:27.4]} 7. d3 {[%clk 0:00:27.1]} 7... h6 {[%clk 0:14:16.1]} 8. g3 {[%clk 0:0
# ...

# %% [markdown]
# ## Get Player Clubs

# %%
get_player_clubs?
# Out:
# Signature: get_player_clubs(username: str, tts=0, **kwargs) -> chessdotcom.types.ChessDotComResponse
# Docstring:
# :param username: username of the player.
# :param tts: the time the client will wait before making the first request.
# :returns: ``ChessDotComResponse`` object containing
#         a list of clubs the player is a member of.
# File:      ~/Documents/Projects/cse6242/project/.venv/lib/python3.10/site-packages/chessdotcom/client.py
# Type:      function

# %%
get_player_clubs(username).json
# Out:
# {'clubs': [{'@id': 'https://www.chess.com/club/chess-comtv',
#    'name': 'Chess.comTV',
#    'last_activity': 1533261072,
#    'icon': 'https://images.chesscomfiles.com/uploads/v1/group/10182.ce48ce37.50x50o.643fa8f292b8.png',
#    'url': 'https://www.chess.com/club/chess-comtv',
#    'joined': 1533261072},
#   {'@id': 'https://www.chess.com/club/club-admins',
#    'name': 'Club Admins',
#    'last_activity': 1724357345,
#    'icon': 'https://images.chesscomfiles.com/uploads/v1/group/77144.b37f1a94.50x50o.916fe9df6e33.png',
#    'url': 'https://www.chess.com/club/club-admins',
#    'joined': 1724357345},
#   {'@id': 'https://www.chess.com/club/saint-louis-archbishops',
#    'name': 'Saint Louis Archbishops',
#    'last_activity': 1679669153,
#    'icon': 'https://images.chesscomfiles.com/uploads/v1/group/307407.e15639e7.50x50o.e53186f27f18.png',
#    'url': 'https://www.chess.com/club/saint-louis-archbishops',
#    'joined': 1679258225},
# ...

# %% [markdown]
# ## Get Leaderboards

# %%
get_leaderboards?
# Out:
# Signature: get_leaderboards(tts=0, **kwargs) -> chessdotcom.types.ChessDotComResponse
# Docstring:
# :param tts: the time the client will wait before making the first request.
# :returns: ``ChessDotComResponse`` object containing
#             information about top 50 player for daily and live games, tactics and lessons.
# File:      ~/Documents/Projects/cse6242/project/.venv/lib/python3.10/site-packages/chessdotcom/client.py
# Type:      function

# %%
get_leaderboards().json.values().__iter__().__next__().keys()
# Out:
# dict_keys(['daily', 'daily960', 'live_rapid', 'live_blitz', 'live_bullet', 'live_bughouse', 'live_blitz960', 'live_threecheck', 'live_crazyhouse', 'live_kingofthehill', 'tactics', 'rush', 'battle'])

# %% [markdown]
# ## Get Streamers

# %%
get_streamers?
# Out:
# Signature: get_streamers(tts=0, **kwargs) -> chessdotcom.types.ChessDotComResponse
# Docstring:
# :param tts: the time the client will wait before making the first request.
# :returns: ``ChessDotComResponse`` object containing
#             information about Chess.com streamers.
# File:      ~/Documents/Projects/cse6242/project/.venv/lib/python3.10/site-packages/chessdotcom/client.py
# Type:      function

# %%
get_streamers().json
# Out:
# {'streamers': [{'username': 'aleibow',
#    'avatar': 'https://images.chesscomfiles.com/uploads/v1/user/44281978.b48234b8.50x50o.4d94277f610c.jpeg',
#    'twitch_url': 'https://twitch.tv/aleibow',
#    'url': 'https://www.chess.com/member/aleibow',
#    'is_live': True,
#    'is_community_streamer': False,
#    'platforms': [{'type': 'twitch',
#      'stream_url': 'https://twitch.tv/aleibow',
#      'channel_url': 'https://twitch.tv/aleibow',
#      'is_live': True,
#      'is_main_live_platform': True}]},
#   {'username': 'slaybaefpv',
#    'avatar': 'https://images.chesscomfiles.com/uploads/v1/user/319985835.01c6461b.50x50o.b61e0f440f53.jpg',
#    'twitch_url': 'https://twitch.tv/slaybaefpv',
#    'url': 'https://www.chess.com/member/slaybaefpv',
#    'is_live': True,
#    'is_community_streamer': False,
#    'platforms': [{'type': 'twitch',
#      'stream_url': 'https://twitch.tv/slaybaefpv',
#      'channel_url': 'https://twitch.tv/slaybaefpv',
#      'is_live': True,
# ...

# %% [markdown]
# ## Get Daily Puzzle

# %%
get_random_daily_puzzle?
# Out:
# Signature: get_random_daily_puzzle(tts=0, **kwargs) -> chessdotcom.types.ChessDotComResponse
# Docstring:
# :param tts: the time the client will wait before making the first request.
# :returns: ``ChessDotComResponse`` object containing
#             information about a randomly picked daily puzzle.
# File:      ~/Documents/Projects/cse6242/project/.venv/lib/python3.10/site-packages/chessdotcom/client.py
# Type:      function

# %%
get_random_daily_puzzle().json
# Out:
# {'puzzle': {'title': 'Mate Or Promotion',
#   'url': 'https://www.chess.com/daily-chess-puzzle/2018-07-25',
#   'publish_time': 1532502000,
#   'fen': '5b2/P4N2/r1p5/3p1kP1/8/p1R5/4KN2/8 w - - 0 1',
#   'pgn': '[Date "????.??.??"]\r\n[Result "*"]\r\n[FEN "5b2/P4N2/r1p5/3p1kP1/8/p1R5/4KN2/8 w - - 0 1"]\r\n\r\n1. Rxc6 Rxc6 2. a8=Q\r\n*',
#   'image': 'https://www.chess.com/dynboard?fen=5b2/P4N2/r1p5/3p1kP1/8/p1R5/4KN2/8%20w%20-%20-%200%201&size=2'}}

# %%
get_current_daily_puzzle?
# Out:
# Signature: get_current_daily_puzzle(tts=0, **kwargs) -> chessdotcom.types.ChessDotComResponse
# Docstring:
# :param tts: the time the client will wait before making the first request.
# :returns: ``ChessDotComResponse`` object containing
#             information about the daily puzzle found in www.chess.com.
# File:      ~/Documents/Projects/cse6242/project/.venv/lib/python3.10/site-packages/chessdotcom/client.py
# Type:      function

# %%
get_current_daily_puzzle().json
# Out:
# {'puzzle': {'title': 'Promote Early and Often',
#   'url': 'https://www.chess.com/daily-chess-puzzle/2024-09-20',
#   'publish_time': 1726815600,
#   'fen': '8/8/3P4/4p1p1/2k1P1P1/1p5p/pK5P/8 b - - 0 55',
#   'pgn': '[Event "FIDE World Rapid Team Chess Championship"]\r\n[Site "?"]\r\n[Date "2024.08.02"]\r\n[Round "?"]\r\n[White "Arjun Erigaisi"]\r\n[Black "Magnus Carlsen"]\r\n[Result "0-1"]\r\n[FEN "8/8/3P4/4p1p1/2k1P1P1/1p5p/pK5P/8 b - - 0 55"]\r\n\r\n55... Kd3 56. d7 a1=Q+ 57. Kxa1 Kc2 58. d8=Q b2+ 59. Ka2 b1=Q+ 60. Ka3 Qb3# 0-1',
#   'image': 'https://www.chess.com/dynboard?fen=8/8/3P4/4p1p1/2k1P1P1/1p5p/pK5P/8%20b%20-%20-%200%2055&size=2'}}

# %% [markdown]
# ## Get Country Details

# %%
get_country_details?
# Out:
# Signature: get_country_details(iso: str, tts=0, **kwargs) -> chessdotcom.types.ChessDotComResponse
# Docstring:
# :param iso: country's 2-character ISO 3166 code.
# :param tts: the time the client will wait before making the first request.
# :returns: ``ChessDotComResponse`` object containing
#             additional details about a country.
# File:      ~/Documents/Projects/cse6242/project/.venv/lib/python3.10/site-packages/chessdotcom/client.py
# Type:      function

# %%
get_country_details("SN").json
# Out:
# {'country': {'@id': 'https://api.chess.com/pub/country/SN',
#   'code': 'SN',
#   'name': 'Senegal'}}

# %%
get_country_clubs?
# Out:
# Signature: get_country_clubs(iso: str, tts=0, **kwargs) -> chessdotcom.types.ChessDotComResponse
# Docstring:
# :param iso: country's 2-character ISO 3166 code.
# :param tts: the time the client will wait before making the first request.
# :returns: ``ChessDotComResponse`` object containing a list of URLs for clubs identified
#             as being in or associated with this country.
# File:      ~/Documents/Projects/cse6242/project/.venv/lib/python3.10/site-packages/chessdotcom/client.py
# Type:      function

# %%
get_country_clubs("SN").json
# Out:
# {'clubs': ['https://api.chess.com/pub/club/chess-league-international--senegal',
#   'https://api.chess.com/pub/club/je-sais-pas',
#   'https://api.chess.com/pub/club/caballos-lechugeros-1',
#   'https://api.chess.com/pub/club/kanye-west',
#   'https://api.chess.com/pub/club/overlord-chess-com',
#   'https://api.chess.com/pub/club/teranga-club',
#   'https://api.chess.com/pub/club/english-interact-club',
#   'https://api.chess.com/pub/club/club-national',
#   'https://api.chess.com/pub/club/legion-of-thies',
#   'https://api.chess.com/pub/club/le-club-de-kabs',
#   'https://api.chess.com/pub/club/mini-ssenegal',
#   'https://api.chess.com/pub/club/checkmatesn',
#   'https://api.chess.com/pub/club/club-echec-et-mat-du-senegal',
#   'https://api.chess.com/pub/club/club-echecs-uidt',
#   'https://api.chess.com/pub/club/zobi-esport',
#   'https://api.chess.com/pub/club/team-senegal-1',
#   'https://api.chess.com/pub/club/club-of-the-bosses',
# ...

# %%
get_country_players?
# Out:
# Signature: get_country_players(iso: str, tts=0, **kwargs) -> chessdotcom.types.ChessDotComResponse
# Docstring:
# :param iso: country's 2-character ISO 3166 code.
# :param tts: the time the client will wait before making the first request.
# :returns: ``ChessDotComResponse`` object containing a list of usernames for players
#             who identify themselves as being in this country.
# File:      ~/Documents/Projects/cse6242/project/.venv/lib/python3.10/site-packages/chessdotcom/client.py
# Type:      function

# %%
get_country_players("SN").json
# Out:
# {'players': ['12cobra34',
#   '1inanbilmiyorum1',
#   '6lackman20',
#   '7171abdourahmanesamba71',
#   '720airbigmac',
#   'abcdefgsxj',
#   'abdarah',
#   'abdelkipre',
#   'abdou-discord',
#   'abdoul1002',
#   'abdoulayeousman',
#   'abebaabiodun',
#   'abeliam0',
#   'acnologia1169',
#   'acub3d',
#   'adams4sn',
#   'adas1315',
#   'afrikone',
#   'ahan_shankar',
#   'ahmadouhane',
#   'ahmadouyes',
#   'akatharvkashyap',
#   'akeela20',
#   'akpadza',
#   'alakers',
#   'alaminediop',
#   'alassane2022',
#   'alatinakbas',
#   'alfa-ahamed',
#   'aliamsid',
#   'alkhadim',
#   'alksdjfhlakdssjfsldkfj',
#   'almadieschess',
#   'almuudo',
#   'amdy7002',
#   'ameths',
#   'amoulsolo3',
#   'angilfantcho',
#   'anthorobsn',
#   'anton-zilwicki',
#   'apex_0626',
#   'apoqlon',
#   'arctium0',
#   'asda_wh',
#   'ashmahmoud',
#   'assanegueye',
#   'averagacha',
#   'aziizly45',
#   'azouboy1',
#   'b0ubacar',
#   'baba-abdi',
#   'babacar15',
#   'babs500',
#   'bachir6c',
# ...
